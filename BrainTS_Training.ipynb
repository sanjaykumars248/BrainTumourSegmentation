# %%
"""
This notebook installs the necessary packages for the Brain Tumour Segmentation project.
It installs the following packages:
- split-folders: A tool to split folders into training, validation, and test sets.
- tabulate: A library to create formatted tables.
"""

! pip install -q split-folders
! pip install -q tabulate

# %%
"""
This script removes the specified directories if they exist.
"""

import shutil

shutil.rmtree('/kaggle/working/BrainTS/', ignore_errors=True)
shutil.rmtree('/kaggle/working/BestModels', ignore_errors=True)
shutil.rmtree('/kaggle/working/logs', ignore_errors=True)

# %%
"""
This script removes the specified zip files if they exist.
"""

import os

try:
    os.remove('/kaggle/working/BestModels.zip')
    os.remove('/kaggle/working/BrainTS.zip')
    os.remove('/kaggle/working/logs.zip')

except FileNotFoundError:
    print(f"No zip files found!")
    pass
# Out:
# No zip files found!

# %%
"""
This script imports the necessary libraries and modules for the Brain Tumour Segmentation project.
"""

import os
import random
import numpy as np
import pandas as pd
import glob
import nibabel as nib
from tqdm import tqdm
import kagglehub
import shutil
import json
from datetime import datetime, timedelta, timezone
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.utils import to_categorical

import tensorflow as tf
import tensorflow.keras.backend as K
import keras.backend as k
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Concatenate, Dropout, Conv2DTranspose, AveragePooling2D
from tensorflow.keras import Model
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy, binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

from tabulate import tabulate
import splitfolders

import warnings
warnings.filterwarnings('ignore')

# %%
"""
This script sets up the configuration for the Brain Tumour Segmentation project.
It includes the following configurations:

- BATCH_SIZE: Batch size for training
- EPOCHS: Number of epochs for training
- DECODER_STAGES: Number of decoder stages
- current_timestamp: Current timestamp in the format YYYYMMDD_HHMMSS
- plot_sample: Boolean to indicate whether to plot sample images
- RATES: List of rates for some process
- LR: Learning rate
- includeT1: Boolean to indicate whether to include T1 images
- shuffle: Boolean to indicate whether to shuffle the data
- datasetInputTrain: Path to the training dataset
- datasetInputTest: Path to the test dataset
- exceptionFolder: Path to the exception folder
- trainPaths: Path to the training data
- testPaths: Path to the test data
- rename355SegSrc: Source path for renaming a specific segmentation file
- rename355SegTgt: Target path for renaming a specific segmentation file
- saveNPYimages: Path to save NPY images
- saveNPYmasks: Path to save NPY masks
- saveTestNPYimages: Path to save test NPY images
- splitInputFolder: Path to the input folder for splitting data
- splitOutputFolder: Path to the output folder for splitting data
- train_img_dir: Directory for training images
- train_mask_dir: Directory for training masks
- val_img_dir: Directory for validation images
- val_mask_dir: Directory for validation masks
- test_img_dir: Directory for test images
- test_mask_dir: Directory for test masks
- loadTrainPath: Path to load the training dataset
- loadTestPath: Path to load the test dataset
- saveBestModelPath: Path to save the best model
- threshold: Threshold value for some process
- SMOOTH: Smoothing value for some process
"""

utc_offset = timezone(timedelta(hours=5, minutes=30))
current_timestamp = datetime.now(utc_offset).strftime("%Y%m%d_%H%M%S")

workingDirectory = os.getcwd()+ '/'


def get_working_directory():
    return workingDirectory


config = {
    "BATCH_SIZE": 16,
    "EPOCHS": 100,
    "DECODER_STAGES": 5,
    "current_timestamp": current_timestamp,
    "plot_sample": False,
    "RATES": [6, 12, 18],
    "LR": 1e-4,
    "includeT1": False,
    "shuffle": True,

    "datasetInputTrain": "/kaggle/input/brats2020/BraTS20/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/",
    "datasetInputTest": "/kaggle/input/brats2020/BraTS20/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/",
    "exceptionFolder": "/kaggle/input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355",

    "trainPaths": f"{workingDirectory}BraTS20/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/",
    "testPaths": f"{workingDirectory}BraTS20/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData",

    "rename355SegSrc": f"{workingDirectory}BraTS20/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355/W39_1998.09.19_Segm.nii",
    "rename355SegTgt": f"{workingDirectory}BraTS20/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355/BraTS20_Training_355_seg.nii",

    "saveNPYimages": f"{workingDirectory}BrainTS/train/input3ch/images/",
    "saveNPYmasks": f"{workingDirectory}BrainTS/train/input3ch/masks/",
    "saveTestNPYimages": f"{workingDirectory}BrainTS/test/input3ch/images/",

    "splitInputFolder": f"{workingDirectory}BrainTS/train/input3ch/",
    "splitOutputFolder": f"{workingDirectory}BrainTS/training/",

    "train_img_dir": f"{workingDirectory}BrainTS/training/train/images/",
    "train_mask_dir": f"{workingDirectory}BrainTS/training/train/masks/",

    "val_img_dir": f"{workingDirectory}BrainTS/training/val/images/",
    "val_mask_dir": f"{workingDirectory}BrainTS/training/val/masks/",

    "test_img_dir": f"{workingDirectory}BrainTS/training/test/images/",
    "test_mask_dir": f"{workingDirectory}BrainTS/training/test/masks/",

    # SET TRAIN AND TEST DATASET PATH
    "loadTrainPath": f"{workingDirectory}BraTS20/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData",
    "loadTestPath": f"{workingDirectory}/BraTS20/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData",

    "saveBestModelPath": f"{workingDirectory}BestModels/",

    "threshold": 0.25,
    "SMOOTH": 1e-6

}

# %%
class BrainTumourDataset:
    """
    A class used to represent the Brain Tumour Dataset and its processing methods.
    """

    def __init__(self):
        """
        Initialize the BrainTumourDataset class.
        """
        super().__init__()
        self.workingDirectory = get_working_directory()
        self.scaler = MinMaxScaler()

    def download_dataset(self):
        """
        Download the BraTS20 dataset if it does not exist in the respective environment.
        """
        chk_dataset = False
        if 'kaggle' in self.workingDirectory:
            chk_dataset = "BraTS2020_TrainingData" not in os.listdir(
                "/kaggle/input/brats2020/BraTS20") and "BraTS2020_ValidationData" not in os.listdir("/kaggle/input/brats2020/BraTS20")
        else:
            chk_dataset = 'BraTS' in os.listdir()

        if chk_dataset:
            try:
                print("Dataset not found. Downloading BraTS20 Dataset...")
                datasetPath = kagglehub.dataset_download("awsaf49/brats20-dataset-training-validation")
                print(f"Path to dataset: {datasetPath}")

                # Moving dataset to working directory
                dst = os.path.join(self.workingDirectory, 'dataset')
                print("Moving dataset to working directory")
                shutil.move(datasetPath, dst)

                print("Renaming dataset to BraTS")
                if "/content/" in self.workingDirectory:
                    os.rename(src=os.path.join(self.workingDirectory, 'dataset'),
                              dst=os.path.join(self.workingDirectory, 'BraTS20'))
                else:
                    os.rename(src=os.path.join(self.workingDirectory, 'dataset/1'),
                              dst=os.path.join(self.workingDirectory, 'BraTS20'))

                print("Renaming incorrect filename...")
                os.rename(config['rename355SegSrc'], config['rename355SegTgt'])

            except Exception as e:
                raise RuntimeError(f"Dataset download failed: {e}")

        else:
            print("Dataset BraTS20 already existing!")

    def _process_image(self, imagePath):
        """
        Load and normalize an image.

        :param imagePath: Path to the image file.
        :return: Normalized image.
        """
        image = nib.load(imagePath).get_fdata()
        image = self.scaler.fit_transform(image.reshape(-1, image.shape[-1])).reshape(image.shape)
        return image

    def _process_mask(self, maskPath):
        """
        Load and process a mask.

        :param maskPath: Path to the mask file.
        :return: Processed mask.
        """
        mask = nib.load(maskPath).get_fdata()
        mask[mask == 4] = 3
        return mask

    @staticmethod
    def _plot_samples(image_slice, mask_slice, slice_idx, load_type):
        """
        Plot sample images and mask for visualization.

        :param image_slice: Slice of the image.
        :param mask_slice: Slice of the mask.
        :param slice_idx: Index of the slice.
        :param load_type: Type of data loading (train/test).
        """
        print(image_slice.shape)
        plt.figure(figsize=(12, 8))
        plt.subplot(2, 4, 1)
        plt.imshow(image_slice[:, :, 0])
        plt.title('FLAIR')
        plt.subplot(2, 4, 2)
        plt.imshow(image_slice[:, :, 1])
        plt.title('T1CE')
        plt.subplot(2, 4, 3)
        plt.imshow(image_slice[:, :, 2])
        plt.title('T2')

        if config['includeT1']:
            plt.subplot(2, 4, 4)
            plt.imshow(image_slice[:, :, 3])
            plt.title('T1')

        if load_type == 'train':
            for i in range(mask_slice.shape[-1]):
                plt.subplot(2, 4, 5 + i)
                plt.imshow(mask_slice[:, :, i])
                plt.title(f"MASK_{i}")
        plt.show()

    def _save_slices(self, image, mask, idx, load_type, plot_sample):
        """
        Save image/mask as .npy files.

        :param image: Image data.
        :param mask: Mask data.
        :param idx: Index of the image.
        :param load_type: Type of data loading (train/test).
        :param plot_sample: Boolean to indicate whether to plot sample images.
        """
        channels = image.shape[2]
        lowerBound = int((channels / 2) - (image.shape[2] / 4))
        upperBound = int((channels / 2) + (image.shape[2] / 4))
        mask_slice = np.empty(0, dtype=np.uint8)
        cnt = 0

        for slice_idx in range(lowerBound, upperBound, 16):
            if load_type == 'train':
                if np.unique(mask[:, :, slice_idx]).any() == 0:
                    continue

                mask_slice = np.expand_dims(mask[:, :, slice_idx], axis=2)
                mask_slice = to_categorical(mask_slice, num_classes=4)

            image_slice = image[:, :, slice_idx]

            if plot_sample:
                self._plot_samples(image_slice, mask_slice, slice_idx, load_type)
                plot_sample = False

            if load_type == 'train':
                os.makedirs(config['saveNPYimages'], exist_ok=True)
                os.makedirs(config["saveNPYmasks"], exist_ok=True)
                np.save(f"{config['saveNPYimages']}BraTS_image_{str(idx + 1).rjust(3, '0')}_{slice_idx}.npy", image_slice)
                np.save(f"{config['saveNPYmasks']}BraTS_mask_{str(idx + 1).rjust(3, '0')}_{slice_idx}.npy", mask_slice)

            else:
                os.makedirs(config['saveTestNPYimages'], exist_ok=True)
                np.save(f"{config['saveTestNPYimages']}BraTS_{str(idx + 1).rjust(3, '0')}_{cnt}.npy", image_slice)

            cnt += 1

    def load_data(self, path, load_type='train', plot_sample=False):
        """
        Load and preprocess dataset.

        :param path: Path to the dataset.
        :param load_type: Type of data loading (train/test).
        :param plot_sample: Boolean to indicate whether to plot sample images.
        """
        os.makedirs(os.path.join(self.workingDirectory, 'BrainTS/'), exist_ok=True)

        chk_train = "train" in os.listdir(os.path.join(self.workingDirectory, 'BrainTS/'))
        chk_test = "test" in os.listdir(os.path.join(self.workingDirectory, 'BrainTS/'))

        if chk_train and load_type == 'train':
            if plot_sample:
                imgPth = f"{config['train_img_dir']}{random.choice(os.listdir(config['train_img_dir']))}"
                print(imgPth)
                img = np.load(imgPth)
                print(img.shape)
                mskPth = imgPth.replace('image', 'mask')
                msk = np.load(mskPth)
                self._plot_samples(img, msk, 0, load_type)
            print(f"NPY {load_type.capitalize()} Dataset BraTS already exists and preprocessed!")

        elif chk_test and load_type == 'test':
            if plot_sample:
                imgPth = f"{config['train_img_dir']}{random.choice(os.listdir(config['train_img_dir']))}"
                img = np.load(imgPth)
                self._plot_samples(img, mask_slice=None, slice_idx=0, load_type=load_type)
            print(f"NPY {load_type.capitalize()} Dataset BraTS already exists and preprocessed!")

        else:
            flair_list = sorted(glob.glob(path + "/*/*flair.nii"))
            t1ce_list = sorted(glob.glob(path + "/*/*t1ce.nii"))
            t2_list = sorted(glob.glob(path + "/*/*t2.nii"))
            if config['includeT1']:
                t1_list = sorted(glob.glob(path + "/*/*t1.nii"))

            for img in tqdm(range(len(flair_list))):
                # FLAIR
                temp_img_flair = self._process_image(flair_list[img])

                # T1
                if config['includeT1']:
                    temp_img_t1 = self._process_image(t1_list[img])

                # T1CE
                temp_img_t1ce = self._process_image(t1ce_list[img])

                # T2
                temp_img_t2 = self._process_image(t2_list[img])

                if config['includeT1']:
                    # Ensure that all input images have the same shape
                    assert temp_img_flair.shape == temp_img_t1.shape == temp_img_t1ce.shape == temp_img_t2.shape, "All input images must have the same shape."
                    # Combine images into 4D array
                    temp_img = np.stack([temp_img_flair, temp_img_t1ce, temp_img_t2, temp_img_t1], axis=-1)
                else:
                    # Ensure that all input images have the same shape
                    assert temp_img_flair.shape == temp_img_t1ce.shape == temp_img_t2.shape, "All input images must have the same shape."
                    # Combine images into 3D array
                    temp_img = np.stack([temp_img_flair, temp_img_t1ce, temp_img_t2], axis=3)

                temp_img = temp_img[24:216, 24:216, 13:141]

                temp_msk = None
                if load_type == 'train':
                    mask_list = sorted(glob.glob(path + "/*/*seg.nii"))
                    temp_msk = self._process_mask(mask_list[img])
                    temp_msk = temp_msk[24:216, 24:216, 13:141]

                self._save_slices(temp_img, temp_msk, img, load_type, plot_sample)

    def split_dataset(self, train_ratio=0.8, test_ratio=0.0, test=False):
        """
        Split dataset into train, test, and validation folders.

        :param train_ratio: Ratio of training data.
        :param test_ratio: Ratio of test data.
        :param test: Boolean to indicate whether to include test data.
        """
        os.makedirs(config['splitOutputFolder'], exist_ok=True)
        chk_trn = 'train' in os.listdir(f"{self.workingDirectory}BrainTS/training")
        chk_val = 'val' in os.listdir(f"{self.workingDirectory}BrainTS/training")

        if not (chk_trn and chk_val):
            assert not (test and test_ratio == 0), "Enter test_ratio > 0 when test=True"
            seed = random.randint(0, 100)
            print(f'Test: {test}')
            if test:
                val_ratio = 1.0 - train_ratio - test_ratio
                splitfolders.ratio(input=config['splitInputFolder'], output=config['splitOutputFolder'],
                                   ratio=(train_ratio, val_ratio, test_ratio), move=False, seed=seed)
            else:
                val_ratio = 1.0 - train_ratio
                splitfolders.ratio(input=config['splitInputFolder'], output=config['splitOutputFolder'],
                                   ratio=(train_ratio, val_ratio), move=False, seed=seed)
        else:
            print(f"Train-Test Split is done!")

# %%
class DataLoader:
    """
    A class used to load and generate batches of images and masks for training.
    """

    def __init__(self, img_dir, msk_dir):
        """
        Initialize the DataLoader class.

        :param img_dir: Directory containing the images.
        :param msk_dir: Directory containing the masks.
        """
        super().__init__()
        self.img_dir = img_dir
        self.msk_dir = msk_dir
        self.batch_size = config['BATCH_SIZE']
        self.workingDirectory = get_working_directory()

    @staticmethod
    def _load_images(folder, fileList):
        """
        Load images/masks from directory based on file names.

        :param folder: Directory containing the files.
        :param fileList: List of file names to load.
        :return: Array of loaded images/masks.
        """
        images = []
        for file in fileList:
            if file.endswith('.npy'):
                filePath = os.path.join(folder, file)
                image = np.load(filePath)
                images.append(image)

        return np.array(images)

    def data_generator(self):
        """
        Generator function to yield images and masks in batches.

        :return: Yields batches of images and masks.
        """
        imageList = sorted(os.listdir(self.img_dir))
        maskList = sorted(os.listdir(self.msk_dir))

        total_samples = len(imageList)
        while True:
            batchStart = 0
            batchEnd = self.batch_size

            while batchStart < total_samples:
                limit = min(batchEnd, total_samples)

                X = self._load_images(self.img_dir, imageList[batchStart:limit])
                Y = self._load_images(self.msk_dir, maskList[batchStart:limit])

                yield X, Y

                batchStart += self.batch_size
                batchEnd += self.batch_size

# %%
SMOOTH = config['SMOOTH']

def iou_metric(y_true, y_pred, smooth=SMOOTH):
    """
    Calculate the Intersection over Union (IoU) metric.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param smooth: Smoothing factor to avoid division by zero.
    :return: Average IoU across all classes.
    """
    y_true_f = tf.reshape(y_true, (-1, y_true.shape[-1]))
    y_pred_f = tf.reshape(y_pred, (-1, y_pred.shape[-1]))

    y_true_f = tf.cast(y_true_f, tf.float32)
    y_pred_f = tf.cast(y_pred_f, tf.float32)

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    union = tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0)

    iou = (intersection + smooth) / (union + smooth)

    return tf.reduce_mean(iou)

def dice_coef(y_true, y_pred, smooth=SMOOTH):
    """
    Calculate the Dice coefficient.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param smooth: Smoothing factor to avoid division by zero.
    :return: Average Dice coefficient across all classes.
    """
    class_num = y_true.shape[-1]    # Number of classes in the prediction
    total_dice = 0.0    # Initialize total Dice coefficient

    for i in range(class_num):
        # Flatten the tensors for each class
        y_true_f = tf.keras.layers.Flatten()(y_true[..., i])
        y_pred_f = tf.keras.layers.Flatten()(y_pred[..., i])

        # Cast tensors to float32
        y_true_f = tf.cast(y_true_f, tf.float32)
        y_pred_f = tf.cast(y_pred_f, tf.float32)

        # Compute intersection and union
        intersection = tf.reduce_sum(y_true_f * y_pred_f)
        union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)

        # Dice coefficient for current class
        dice = (2. * intersection + smooth) / (union + smooth)
        
        # Accumulate the Dice score
        total_dice += dice
    
    # Return average Dice coefficient across all classes
    return total_dice / class_num

def dice_coef_necrotic(y_true, y_pred, epsilon=SMOOTH):
    """
    Calculate the Dice coefficient for necrotic tumor.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param epsilon: Smoothing factor to avoid division by zero.
    :return: Dice coefficient for necrotic tumor.
    """
    y_true_f = K.cast(y_true, 'float32')
    y_pred_f = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true_f[:, :, 1] * y_pred_f[:, :, 1])
    return (2. * intersection + epsilon) / (K.sum(y_true_f[:, :, 1]) + K.sum(y_pred_f[:, :, 1]) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=SMOOTH):
    """
    Calculate the Dice coefficient for edema tumor.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param epsilon: Smoothing factor to avoid division by zero.
    :return: Dice coefficient for edema tumor.
    """
    y_true_f = K.cast(y_true, 'float32')
    y_pred_f = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true_f[:, :, 2] * y_pred_f[:, :, 2])
    return (2. * intersection + epsilon) / (K.sum(y_true_f[:, :, 2]) + K.sum(y_pred_f[:, :, 2]) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=SMOOTH):
    """
    Calculate the Dice coefficient for enhancing tumor.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param epsilon: Smoothing factor to avoid division by zero.
    :return: Dice coefficient for enhancing tumor.
    """
    y_true_f = K.cast(y_true, 'float32')
    y_pred_f = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true_f[:, :, 3] * y_pred_f[:, :, 3])
    return (2. * intersection + epsilon) / (K.sum(y_true_f[:, :, 3]) + K.sum(y_pred_f[:, :, 3]) + epsilon)

def dice_coef_no_tumour(y_true, y_pred, epsilon=SMOOTH):
    """
    Calculate the Dice coefficient for no tumor.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param epsilon: Smoothing factor to avoid division by zero.
    :return: Dice coefficient for no tumor.
    """
    y_true_f = K.cast(y_true, 'float32')
    y_pred_f = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true_f[:, :, 0] * y_pred_f[:, :, 0])
    return (2. * intersection + epsilon) / (K.sum(y_true_f[:, :, 0]) + K.sum(y_pred_f[:, :, 0]) + epsilon)

def precision(y_true, y_pred):
    """
    Calculate the precision metric.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :return: Precision metric.
    """
    y_true_f = K.cast(K.flatten(y_true), 'float32')
    y_pred_f = K.cast(K.flatten(y_pred), 'float32')

    true_positives = K.sum(K.round(K.clip(y_true_f * y_pred_f, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred_f, 0, 1)))

    return true_positives / (predicted_positives + K.epsilon())

def sensitivity(y_true, y_pred):
    """
    Calculate the sensitivity (recall) metric.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :return: Sensitivity metric.
    """
    y_true_f = K.cast(K.flatten(y_true), 'float32')
    y_pred_f = K.cast(K.flatten(y_pred), 'float32')

    true_positives = K.sum(K.round(K.clip(y_true_f * y_pred_f, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true_f, 0, 1)))

    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    """
    Calculate the specificity metric.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :return: Specificity metric.
    """
    y_true_f = K.cast(K.flatten(y_true), 'float32')
    y_pred_f = K.cast(K.flatten(y_pred), 'float32')

    true_negatives = K.sum(K.round(K.clip((1 - y_true_f) * (1 - y_pred_f), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true_f, 0, 1)))

    return true_negatives / (possible_negatives + K.epsilon())

def total_loss(y_true, y_pred, num_classes):
    """
    Calculate the total loss, which is a combination of categorical/binary cross-entropy, Dice loss, and IoU loss.

    :param y_true: Ground truth labels.
    :param y_pred: Predicted labels.
    :param num_classes: Number of classes in the prediction.
    :return: Total loss.
    """
    if num_classes > 1:
        ce_loss = categorical_crossentropy(y_true, y_pred)
    else:
        ce_loss = binary_crossentropy(y_true, y_pred)

    dice_loss = 1.0 - dice_coef(y_true, y_pred)
    iou_loss = 1.0 - iou_metric(y_true, y_pred)

    TOTAL_LOSS = ce_loss + dice_loss + iou_loss

    return TOTAL_LOSS

# %%
class ModelTrainer:
    """
    A class used to train and evaluate the model for brain tumour segmentation.
    """

    def __init__(self, model):
        """
        Initialize the ModelTrainer class.

        :param model: The model to be trained and evaluated.
        """
        super().__init__()
        self.model = model
        self.LR = config['LR']
        self.compile_model()

    def compile_model(self):
        """
        Compile the model with an Adam optimizer and appropriate loss function.
        """
        def loss_fn(y_true, y_pred):
            return total_loss(y_true, y_pred, self.model.num_classes)

        metrics = [
            'accuracy',
            iou_metric,
            dice_coef,
            precision,
            sensitivity,
            specificity,
            dice_coef_necrotic,
            dice_coef_edema,
            dice_coef_enhancing,
            dice_coef_no_tumour
        ]

        self.model.model.compile(
            optimizer=Adam(learning_rate=self.LR),
            loss=loss_fn,
            metrics=metrics
        )

    def train(self, train_gen, val_gen, epochs, steps_per_epoch, validation_steps, model_save_path):
        """
        Train the model using the provided data generators.

        :param train_gen: Training data generator.
        :param val_gen: Validation data generator.
        :param epochs: Number of epochs to train the model.
        :param steps_per_epoch: Number of steps per epoch.
        :param validation_steps: Number of validation steps.
        :param model_save_path: Path to save the best model.
        :return: Training history.
        """
        log_file_path = model_save_path.replace(".keras", "_logs.csv")

        # Check if log file exists else create
        if not os.path.exists(log_file_path):
            os.makedirs(config["saveBestModelPath"], exist_ok=True)
            df = pd.DataFrame()  
            df.to_csv(log_file_path)
            
        callbacks = [
            ModelCheckpoint(model_save_path, monitor='val_loss', mode='min', save_best_only=True, verbose=1),
            CSVLogger(log_file_path, append=True)
            # EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
        ]

        tensorboard_callback = tf.keras.callbacks.TensorBoard(f"{workingDirectory}logs/{model_save_path.split('/')[-1].split('__')[1]}")

        history = self.model.model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[callbacks, tensorboard_callback]
        )

        # Save history to a text file
        history_file_path = model_save_path.replace(".keras", "_history.txt")
        with open(history_file_path, 'w') as f:
            json.dump(history.history, f, indent=4)  # Save as JSON for better readability

        return history

    def evaluate(self, data_gen, steps):
        """
        Evaluate the model on the test data generator.

        :param data_gen: Test data generator.
        :param steps: Number of steps for evaluation.
        :return: Evaluation results.
        """
        return self.model.model.evaluate(data_gen, steps=steps)

    def predict(self, data, verbose=1):
        """
        Predict the output for the given input data.

        :param data: Input data for prediction.
        :param verbose: Verbosity mode.
        :return: Predicted output.
        """
        return self.model.model.predict(data, verbose=verbose)

# %%
class ResNet50:
    """
    A class used to build and manage a ResNet50-based model for brain tumour segmentation.
    """

    def __init__(self, input_shape, num_classes=1):
        """
        Initialize the ResNet50 class.

        :param input_shape: Shape of the input images.
        :param num_classes: Number of output classes.
        """
        super().__init__()
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.model = self.build_resnet50()

    @staticmethod
    def _conv_block(x, num_filters):
        """
        Create a convolutional block with Conv2D, LeakyReLU, and Dropout layers.

        :param x: Input tensor.
        :param num_filters: Number of filters for the Conv2D layers.
        :return: Output tensor.
        """
        x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
        x = LeakyReLU(negative_slope=0.0001)(x)
        x = Dropout(0.2)(x)
        x = Conv2D(num_filters, 3, padding="same", kernel_initializer="he_normal")(x)
        x = LeakyReLU(negative_slope=0.0001)(x)
        return x

    @staticmethod
    def _encoder_block(self, x, num_filters):
        """
        Create an encoder block with convolutional and max pooling layers.

        :param x: Input tensor.
        :param num_filters: Number of filters for the Conv2D layers.
        :return: Tuple of output tensor and pooled tensor.
        """
        x = self._conv_block(x, num_filters)
        p = MaxPooling2D(pool_size=(2, 2))(x)
        return x, p

    @staticmethod
    def _decoder_block(self, x, skip_cxn, num_filters, kernel_size=(2, 2), strides=2):
        """
        Create a decoder block with Conv2DTranspose and concatenation layers.

        :param x: Input tensor.
        :param skip_cxn: Skip connection tensor.
        :param num_filters: Number of filters for the Conv2D layers.
        :param kernel_size: Kernel size for the Conv2DTranspose layer.
        :param strides: Strides for the Conv2DTranspose layer.
        :return: Output tensor.
        """
        x = Conv2DTranspose(num_filters, kernel_size=kernel_size, strides=strides, padding="same")(x)
        if skip_cxn is not None:
            x = Concatenate()([x, skip_cxn])
        x = self._conv_block(x, num_filters)
        return x

    def build_resnet50(self):
        """
        Build the ResNet50 model with custom modifications for brain tumour segmentation.

        :return: Compiled ResNet50 model.
        """
        ip = Input(shape=self.input_shape)

        # CONTRACTING PATH: Load ResNet50V2 and modify first layer to accept 4 channels
        base_encoder = ResNet50V2(include_top=False, weights='imagenet', input_tensor=ip)
        base_encoder.trainable = False  # Freeze the base encoder layers

        # Modify the first layer of ResNet50V2 to accept 4 channels (instead of 3 channels)
        # base_encoder.layers[0] = Conv2D(64, (7, 7), padding="same", strides=(2, 2), use_bias=False, kernel_initializer=RandomNormal(mean=0.0, stddev=0.05), input_shape=self.input_shape)

        skip_connections = [
            base_encoder.get_layer("conv1_conv").output,
            base_encoder.get_layer("conv2_block3_out").output,
            base_encoder.get_layer("conv3_block4_out").output,
            base_encoder.get_layer("conv4_block6_out").output
        ]

        # BOTTLENECK
        b = base_encoder.output

        # EXPANDING PATH
        d1 = self._decoder_block(self, x=b, skip_cxn=skip_connections[3], num_filters=1024, kernel_size=(1, 1), strides=1)
        d2 = self._decoder_block(self, x=d1, skip_cxn=skip_connections[2], num_filters=512, kernel_size=(2, 2), strides=2)
        d3 = self._decoder_block(self, x=d2, skip_cxn=skip_connections[1], num_filters=256, kernel_size=(2, 2), strides=2)
        d4 = self._decoder_block(self, x=d3, skip_cxn=skip_connections[0], num_filters=64, kernel_size=(4, 4), strides=4)
        d5 = self._decoder_block(self, x=d4, skip_cxn=None, num_filters=32, kernel_size=(2, 2), strides=2)

        if self.num_classes == 1:
            op = Conv2D(self.num_classes, 1, padding="same", activation="sigmoid")(d5)
        else:
            op = Conv2D(self.num_classes, 1, padding="same", activation="softmax")(d5)

        k.clear_session()
        model = Model(inputs=ip, outputs=op, name="ResNet50V2")
        return model

    def summary(self):
        """
        Print the summary of the model.

        :return: Model summary.
        """
        return self.model.summary()

    def get_model_name(self):
        """
        Get the name of the model.

        :return: Model name.
        """
        return self.model.name


class ResNet50_ASPP(ResNet50):
    """
    A class used to build and manage a ResNet50-based model with Atrous Spatial Pyramid Pooling (ASPP) for brain tumour segmentation.
    """

    def __init__(self, input_shape, num_classes=1):
        """
        Initialize the ResNet50_ASPP class.

        :param input_shape: Shape of the input images.
        :param num_classes: Number of output classes.
        """
        super().__init__(input_shape, num_classes)
        self.model = self.build_resnet50_aspp()

    @staticmethod
    def _aspp_block(x, num_filters, rates):
        """
        Atrous Spatial Pyramid Pooling (ASPP) block.

        :param x: Input tensor.
        :param num_filters: Number of filters for the Conv2D layers.
        :param rates: Dilation rates for the atrous convolutions.
        :return: Output tensor.
        """
        # 1x1 Convolution
        conv_1x1 = Conv2D(num_filters, 1, activation="relu", padding="same")(x)

        # Atrous Convolutions with different dilation rates
        conv_3x3_1 = Conv2D(num_filters, 3, dilation_rate=rates[0], activation="relu", padding="same")(x)
        conv_3x3_2 = Conv2D(num_filters, 3, dilation_rate=rates[1], activation="relu", padding="same")(x)
        conv_3x3_3 = Conv2D(num_filters, 3, dilation_rate=rates[2], activation="relu", padding="same")(x)

        # Image Pooling
        image_pooling = AveragePooling2D(pool_size=(x.shape[1], x.shape[2]))(x)
        image_pooling = Conv2D(num_filters, 1, activation="relu", padding="same")(image_pooling)
        image_pooling = UpSampling2D(size=(x.shape[1], x.shape[2]), interpolation='bilinear')(image_pooling)

        # Concatenate all outputs
        x = Concatenate()([conv_1x1, conv_3x3_1, conv_3x3_2, conv_3x3_3, image_pooling])

        # 1x1 Convolution to reduce channels
        x = Conv2D(num_filters, 1, activation="relu", padding="same")(x)
        return x

    def build_resnet50_aspp(self):
        """
        Build the ResNet50 model with ASPP for brain tumour segmentation.

        :return: Compiled ResNet50_ASPP model.
        """
        ip = Input(shape=self.input_shape)

        # CONTRACTING PATH: Load ResNet50V2 and modify first layer to accept 4 channels
        base_encoder = ResNet50V2(include_top=False, weights='imagenet', input_tensor=ip)
        base_encoder.trainable = False  # Freeze the base encoder layers

        # Modify the first layer of ResNet50V2 to accept 4 channels (instead of 3 channels)
        # base_encoder.layers[0] = Conv2D(64, (7, 7), padding="same", strides=(2, 2), use_bias=False, kernel_initializer=RandomNormal(mean=0.0, stddev=0.05), input_shape=self.input_shape)(ip)

        skip_connections = [
            base_encoder.get_layer("conv1_conv").output,
            base_encoder.get_layer("conv2_block3_out").output,
            base_encoder.get_layer("conv3_block4_out").output,
            base_encoder.get_layer("conv4_block6_out").output
        ]

        # ASPP for skip connections
        aspp_skip_connections = [
            self._aspp_block(skip_connections[i], skip_connections[i].shape[3], rates=config['RATES'])
            for i in range(len(skip_connections))
        ]

        # BOTTLENECK
        b = base_encoder.output

        # EXPANDING PATH
        d1 = self._decoder_block(self, x=b, skip_cxn=aspp_skip_connections[3], num_filters=1024, kernel_size=(1, 1), strides=1)
        d2 = self._decoder_block(self, x=d1, skip_cxn=aspp_skip_connections[2], num_filters=512, kernel_size=(2, 2), strides=2)
        d3 = self._decoder_block(self, x=d2, skip_cxn=aspp_skip_connections[1], num_filters=256, kernel_size=(2, 2), strides=2)
        d4 = self._decoder_block(self, x=d3, skip_cxn=aspp_skip_connections[0], num_filters=64, kernel_size=(4, 4), strides=4)
        d5 = self._decoder_block(self, x=d4, skip_cxn=None, num_filters=32, kernel_size=(2, 2), strides=2)

        if self.num_classes == 1:
            op = Conv2D(self.num_classes, 1, padding="same", activation="sigmoid")(d5)
        else:
            op = Conv2D(self.num_classes, 1, padding="same", activation="softmax")(d5)

        k.clear_session()
        model = Model(inputs=ip, outputs=op, name='ResNet50V2_ASPP')
        return model

    def summary(self, line_length=None, positions=None, print_fn=None):
        """
        Print the summary of the model.

        :return: Model summary.
        """
        return self.model.summary(line_length = line_length, positions = positions, print_fn = print_fn)

    def get_model_name(self):
        """
        Get the name of the model.

        :return: Model name.
        """
        return self.model.name

# %%
"""
This script sets up the working directory, downloads the BraTS20 dataset, and processes the training and testing data.
It also splits the dataset into training, validation, and test sets.
"""

print(f"Working Directory: {get_working_directory()}")

dataProcessor = BrainTumourDataset()
print(f"Downloading the BraTS20 dataset...")

dataProcessor.download_dataset()

print(f"Load Training Data")

if os.path.exists('BrainTS/train/input3ch/images/'):
    if config['includeT1'] == True and np.load('BrainTS/train/input3ch/images/' + random.choice(os.listdir('BrainTS/train/input3ch/images/'))).shape[-1] == 4:
        print(f"Include T1: {config['includeT1']} and channels: {np.load('BrainTS/train/input3ch/images/' + random.choice(os.listdir('BrainTS/train/input3ch/images/'))).shape[-1]}")
        pass
    elif config['includeT1'] == False and np.load('BrainTS/train/input3ch/images/' + random.choice(os.listdir('BrainTS/train/input3ch/images/'))).shape[-1] == 3:
        print(f"Include T1: {config['includeT1']} and channels: {np.load('BrainTS/train/input3ch/images/' + random.choice(os.listdir('BrainTS/train/input3ch/images/'))).shape[-1]}")
        pass
    else:
        try:
            print(f"Include T1: {config['includeT1']} and channels: {np.load('BrainTS/train/input3ch/images/' + random.choice(os.listdir('BrainTS/train/input3ch/images/'))).shape[-1]}")
            print(f"Removing the dir BrainTS and reloading")
            shutil.rmtree('BrainTS', ignore_errors=True)
        except:
            pass

dataProcessor.load_data(path=config['datasetInputTrain'], load_type='train', plot_sample=config['plot_sample'])

print(f"Load Testing Data")
dataProcessor.load_data(path=config['datasetInputTest'], load_type='test', plot_sample=config['plot_sample'])

print(f"Train Val Split Folders")
if config["shuffle"]:
    print("Shuffling Train-Val-Test Split")
    shutil.rmtree(f"{workingDirectory}/BrainTS/training", ignore_errors=True)
dataProcessor.split_dataset(train_ratio=0.7, test_ratio=0.15, test=True)
# Out:
# Working Directory: /kaggle/working/
# Downloading the BraTS20 dataset...
# Dataset BraTS20 already existing!
# Load Training Data
# 100%|██████████| 369/369 [08:43<00:00,  1.42s/it]
# Load Testing Data
# 100%|██████████| 125/125 [02:16<00:00,  1.09s/it]
# Train Val Split Folders
# Shuffling Train-Val-Test Split
# Test: True
# Copying files: 2216 files [00:07, 281.22 files/s]

# %%
"""
This script sets up the data loaders for training and validation data, and prints the shapes of the data batches.
"""

INPUT_SHAPE = (256, 256, 3)
NUM_CLASSES = 4

trainDataLoader = DataLoader(config['train_img_dir'], config['train_mask_dir'])
trainDataGen = trainDataLoader.data_generator()

for batch in trainDataGen:
    X, Y = batch
    INPUT_SHAPE = X.shape[1:]
    NUM_CLASSES = Y.shape[-1]
    print(f"Train Generator X:{X.shape}\tY:{Y.shape}")
    print(f"Train Generator X:{X.shape}\tY:{Y.shape[-1]}")
    break

valDataLoader = DataLoader(config['val_img_dir'], config['val_mask_dir'])
valDataGen = valDataLoader.data_generator()

for batch in valDataGen:
    X, Y = batch
    print(f"Validation Generator X:{X.shape}\tY:{Y.shape}")
    break
# Out:
# Train Generator X:(16, 192, 192, 3)	Y:(16, 192, 192, 4)
# Train Generator X:(16, 192, 192, 3)	Y:4
# Validation Generator X:(16, 192, 192, 3)	Y:(16, 192, 192, 4)

# %%
"""
This script calculates and prints the number of steps per epoch for training and validation data.
"""

steps_per_epoch = len(sorted(os.listdir(config['train_img_dir']))) // config['BATCH_SIZE']
val_steps_per_epoch = len(sorted(os.listdir(config['val_img_dir']))) // config['BATCH_SIZE']

print(f"steps_per_epoch: {steps_per_epoch}")
print(f"val_steps_per_epoch: {val_steps_per_epoch}")
# Out:
# steps_per_epoch: 48
# val_steps_per_epoch: 10

# %%
"""
This script initializes the ResNet50_ASPP model for brain tumour segmentation and prints the model name.
"""

resnet_aspp = ResNet50_ASPP(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES)
resnet_aspp_name = resnet_aspp.get_model_name()
print(f"ResNet Name: {resnet_aspp_name}")
# resnet_aspp.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# ResNet Name: ResNet50V2_ASPP

# %%
# %%time
"""
This script initializes the ModelTrainer class with the ResNet50_ASPP model and trains the model using the training and validation data generators.
"""

ResNetAsppModelTrain = ModelTrainer(model=resnet_aspp)
ResNetAsppModelTrain.train(
    train_gen=trainDataGen,
    val_gen=valDataGen,
    epochs=config['EPOCHS'],
    steps_per_epoch=steps_per_epoch,
    validation_steps=val_steps_per_epoch,
    model_save_path=f"{config['saveBestModelPath']}{resnet_aspp_name}__{config['current_timestamp']}.keras"
)
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.8306 - dice_coef: 0.2254 - dice_coef_edema: 0.6625 - dice_coef_enhancing: 0.7793 - dice_coef_necrotic: 0.7375 - dice_coef_no_tumour: 0.5195 - iou_metric: 0.1127 - loss: 1.9930 - precision: 0.8867 - sensitivity: 0.7277 - specificity: 0.9777
# Epoch 1: val_loss improved from inf to 1.54175, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 133s 2s/step - accuracy: 0.8322 - dice_coef: 0.2262 - dice_coef_edema: 0.6665 - dice_coef_enhancing: 0.7823 - dice_coef_necrotic: 0.7407 - dice_coef_no_tumour: 0.5239 - iou_metric: 0.1131 - loss: 1.9892 - precision: 0.8876 - sensitivity: 0.7308 - specificity: 0.9778 - val_accuracy: 0.9546 - val_dice_coef: 0.3505 - val_dice_coef_edema: 0.9996 - val_dice_coef_enhancing: 0.9995 - val_dice_coef_necrotic: 0.9992 - val_dice_coef_no_tumour: 0.9926 - val_iou_metric: 0.1752 - val_loss: 1.5417 - val_precision: 0.9749 - val_sensitivity: 0.9443 - val_specificity: 0.9919
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9595 - dice_coef: 0.3648 - dice_coef_edema: 0.9996 - dice_coef_enhancing: 0.9995 - dice_coef_necrotic: 0.9990 - dice_coef_no_tumour: 0.9898 - iou_metric: 0.1824 - loss: 1.5162 - precision: 0.9811 - sensitivity: 0.9496 - specificity: 0.9939
# Epoch 2: val_loss improved from 1.54175 to 1.53045, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - accuracy: 0.9595 - dice_coef: 0.3650 - dice_coef_edema: 0.9996 - dice_coef_enhancing: 0.9995 - dice_coef_necrotic: 0.9990 - dice_coef_no_tumour: 0.9898 - iou_metric: 0.1825 - loss: 1.5160 - precision: 0.9811 - sensitivity: 0.9494 - specificity: 0.9939 - val_accuracy: 0.9580 - val_dice_coef: 0.3589 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 0.9999 - val_dice_coef_no_tumour: 0.9990 - val_iou_metric: 0.1795 - val_loss: 1.5305 - val_precision: 0.9696 - val_sensitivity: 0.9540 - val_specificity: 0.9900
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9635 - dice_coef: 0.3971 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9998 - dice_coef_necrotic: 0.9995 - dice_coef_no_tumour: 0.9953 - iou_metric: 0.1985 - loss: 1.4529 - precision: 0.9827 - sensitivity: 0.9514 - specificity: 0.9944
# Epoch 3: val_loss improved from 1.53045 to 1.49067, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - accuracy: 0.9635 - dice_coef: 0.3975 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9998 - dice_coef_necrotic: 0.9995 - dice_coef_no_tumour: 0.9953 - iou_metric: 0.1987 - loss: 1.4523 - precision: 0.9827 - sensitivity: 0.9514 - specificity: 0.9944 - val_accuracy: 0.9621 - val_dice_coef: 0.4021 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 0.9997 - val_iou_metric: 0.2011 - val_loss: 1.4907 - val_precision: 0.9656 - val_sensitivity: 0.9605 - val_specificity: 0.9886
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9663 - dice_coef: 0.4627 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9999 - dice_coef_necrotic: 0.9997 - dice_coef_no_tumour: 0.9965 - iou_metric: 0.2314 - loss: 1.3545 - precision: 0.9732 - sensitivity: 0.9624 - specificity: 0.9912
# Epoch 4: val_loss improved from 1.49067 to 1.41916, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - accuracy: 0.9663 - dice_coef: 0.4634 - dice_coef_edema: 0.9999 - dice_coef_enhancing: 0.9999 - dice_coef_necrotic: 0.9997 - dice_coef_no_tumour: 0.9965 - iou_metric: 0.2317 - loss: 1.3535 - precision: 0.9731 - sensitivity: 0.9624 - specificity: 0.9911 - val_accuracy: 0.9662 - val_dice_coef: 0.4550 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 0.9999 - val_iou_metric: 0.2275 - val_loss: 1.4192 - val_precision: 0.9664 - val_sensitivity: 0.9659 - val_specificity: 0.9888
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.9725 - dice_coef: 0.5800 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 0.9999 - dice_coef_necrotic: 0.9998 - dice_coef_no_tumour: 0.9965 - iou_metric: 0.2900 - loss: 1.1798 - precision: 0.9738 - sensitivity: 0.9719 - specificity: 0.9913
# Epoch 5: val_loss improved from 1.41916 to 1.26730, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - accuracy: 0.9724 - dice_coef: 0.5801 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 0.9999 - dice_coef_necrotic: 0.9998 - dice_coef_no_tumour: 0.9965 - iou_metric: 0.2901 - loss: 1.1796 - precision: 0.9737 - sensitivity: 0.9718 - specificity: 0.9912 - val_accuracy: 0.9575 - val_dice_coef: 0.5340 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 0.9999 - val_iou_metric: 0.2670 - val_loss: 1.2673 - val_precision: 0.9587 - val_sensitivity: 0.9566 - val_specificity: 0.9863
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9711 - dice_coef: 0.6121 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 0.9999 - dice_coef_no_tumour: 0.9986 - iou_metric: 0.3060 - loss: 1.1413 - precision: 0.9723 - sensitivity: 0.9708 - specificity: 0.9908
# Epoch 6: val_loss improved from 1.26730 to 1.17126, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 383ms/step - accuracy: 0.9711 - dice_coef: 0.6124 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 0.9999 - dice_coef_no_tumour: 0.9986 - iou_metric: 0.3062 - loss: 1.1408 - precision: 0.9723 - sensitivity: 0.9708 - specificity: 0.9908 - val_accuracy: 0.9574 - val_dice_coef: 0.5984 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.2992 - val_loss: 1.1713 - val_precision: 0.9587 - val_sensitivity: 0.9570 - val_specificity: 0.9863
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9715 - dice_coef: 0.6532 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 0.9998 - dice_coef_no_tumour: 0.9984 - iou_metric: 0.3266 - loss: 1.0703 - precision: 0.9723 - sensitivity: 0.9711 - specificity: 0.9908
# Epoch 7: val_loss improved from 1.17126 to 1.06843, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 391ms/step - accuracy: 0.9716 - dice_coef: 0.6533 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 0.9998 - dice_coef_no_tumour: 0.9984 - iou_metric: 0.3267 - loss: 1.0700 - precision: 0.9724 - sensitivity: 0.9712 - specificity: 0.9908 - val_accuracy: 0.9717 - val_dice_coef: 0.6544 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3272 - val_loss: 1.0684 - val_precision: 0.9723 - val_sensitivity: 0.9714 - val_specificity: 0.9908
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9784 - dice_coef: 0.7190 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9997 - iou_metric: 0.3595 - loss: 0.9597 - precision: 0.9791 - sensitivity: 0.9783 - specificity: 0.9930
# Epoch 8: val_loss did not improve from 1.06843
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9784 - dice_coef: 0.7191 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9997 - iou_metric: 0.3596 - loss: 0.9595 - precision: 0.9791 - sensitivity: 0.9783 - specificity: 0.9930 - val_accuracy: 0.9693 - val_dice_coef: 0.6556 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3278 - val_loss: 1.0691 - val_precision: 0.9696 - val_sensitivity: 0.9688 - val_specificity: 0.9899
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9790 - dice_coef: 0.7386 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3693 - loss: 0.9297 - precision: 0.9795 - sensitivity: 0.9788 - specificity: 0.9932
# Epoch 9: val_loss did not improve from 1.06843
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9790 - dice_coef: 0.7387 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3693 - loss: 0.9294 - precision: 0.9795 - sensitivity: 0.9789 - specificity: 0.9932 - val_accuracy: 0.9692 - val_dice_coef: 0.6608 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3304 - val_loss: 1.0687 - val_precision: 0.9697 - val_sensitivity: 0.9693 - val_specificity: 0.9899
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9778 - dice_coef: 0.7295 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9998 - iou_metric: 0.3647 - loss: 0.9454 - precision: 0.9783 - sensitivity: 0.9777 - specificity: 0.9928
# Epoch 10: val_loss did not improve from 1.06843
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9779 - dice_coef: 0.7298 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9998 - iou_metric: 0.3649 - loss: 0.9448 - precision: 0.9783 - sensitivity: 0.9778 - specificity: 0.9928 - val_accuracy: 0.9745 - val_dice_coef: 0.6128 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3064 - val_loss: 1.1442 - val_precision: 0.9748 - val_sensitivity: 0.9745 - val_specificity: 0.9916
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9763 - dice_coef: 0.7128 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9996 - iou_metric: 0.3564 - loss: 0.9767 - precision: 0.9766 - sensitivity: 0.9761 - specificity: 0.9922
# Epoch 11: val_loss did not improve from 1.06843
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9763 - dice_coef: 0.7134 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9996 - iou_metric: 0.3567 - loss: 0.9757 - precision: 0.9767 - sensitivity: 0.9761 - specificity: 0.9922 - val_accuracy: 0.9748 - val_dice_coef: 0.6415 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3208 - val_loss: 1.1041 - val_precision: 0.9751 - val_sensitivity: 0.9749 - val_specificity: 0.9917
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9754 - dice_coef: 0.6810 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3405 - loss: 1.0326 - precision: 0.9757 - sensitivity: 0.9752 - specificity: 0.9919
# Epoch 12: val_loss improved from 1.06843 to 1.01492, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - accuracy: 0.9754 - dice_coef: 0.6819 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3409 - loss: 1.0311 - precision: 0.9758 - sensitivity: 0.9753 - specificity: 0.9919 - val_accuracy: 0.9759 - val_dice_coef: 0.6907 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3454 - val_loss: 1.0149 - val_precision: 0.9765 - val_sensitivity: 0.9758 - val_specificity: 0.9922
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9795 - dice_coef: 0.7276 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3638 - loss: 0.9490 - precision: 0.9800 - sensitivity: 0.9794 - specificity: 0.9933
# Epoch 13: val_loss improved from 1.01492 to 0.98327, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 388ms/step - accuracy: 0.9796 - dice_coef: 0.7283 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3641 - loss: 0.9478 - precision: 0.9800 - sensitivity: 0.9795 - specificity: 0.9934 - val_accuracy: 0.9754 - val_dice_coef: 0.7046 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3523 - val_loss: 0.9833 - val_precision: 0.9757 - val_sensitivity: 0.9752 - val_specificity: 0.9919
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9814 - dice_coef: 0.7613 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3807 - loss: 0.8900 - precision: 0.9818 - sensitivity: 0.9812 - specificity: 0.9939
# Epoch 14: val_loss improved from 0.98327 to 0.96965, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.9814 - dice_coef: 0.7619 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3809 - loss: 0.8891 - precision: 0.9819 - sensitivity: 0.9813 - specificity: 0.9940 - val_accuracy: 0.9797 - val_dice_coef: 0.7172 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3586 - val_loss: 0.9697 - val_precision: 0.9801 - val_sensitivity: 0.9797 - val_specificity: 0.9934
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9828 - dice_coef: 0.7803 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3902 - loss: 0.8612 - precision: 0.9831 - sensitivity: 0.9827 - specificity: 0.9944
# Epoch 15: val_loss improved from 0.96965 to 0.94903, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9828 - dice_coef: 0.7808 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.3904 - loss: 0.8604 - precision: 0.9831 - sensitivity: 0.9828 - specificity: 0.9944 - val_accuracy: 0.9801 - val_dice_coef: 0.7294 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3647 - val_loss: 0.9490 - val_precision: 0.9806 - val_sensitivity: 0.9802 - val_specificity: 0.9935
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9837 - dice_coef: 0.7928 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3964 - loss: 0.8412 - precision: 0.9840 - sensitivity: 0.9836 - specificity: 0.9947
# Epoch 16: val_loss did not improve from 0.94903
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9837 - dice_coef: 0.7932 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3966 - loss: 0.8406 - precision: 0.9840 - sensitivity: 0.9837 - specificity: 0.9947 - val_accuracy: 0.9785 - val_dice_coef: 0.7302 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3651 - val_loss: 0.9509 - val_precision: 0.9791 - val_sensitivity: 0.9787 - val_specificity: 0.9930
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9847 - dice_coef: 0.8037 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4019 - loss: 0.8233 - precision: 0.9850 - sensitivity: 0.9846 - specificity: 0.9950
# Epoch 17: val_loss improved from 0.94903 to 0.93861, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 388ms/step - accuracy: 0.9847 - dice_coef: 0.8040 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4020 - loss: 0.8229 - precision: 0.9850 - sensitivity: 0.9846 - specificity: 0.9950 - val_accuracy: 0.9790 - val_dice_coef: 0.7381 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3691 - val_loss: 0.9386 - val_precision: 0.9796 - val_sensitivity: 0.9792 - val_specificity: 0.9932
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9848 - dice_coef: 0.8063 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4032 - loss: 0.8197 - precision: 0.9850 - sensitivity: 0.9847 - specificity: 0.9950
# Epoch 18: val_loss did not improve from 0.93861
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9848 - dice_coef: 0.8065 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4033 - loss: 0.8194 - precision: 0.9850 - sensitivity: 0.9847 - specificity: 0.9950 - val_accuracy: 0.9797 - val_dice_coef: 0.7276 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3638 - val_loss: 0.9617 - val_precision: 0.9804 - val_sensitivity: 0.9801 - val_specificity: 0.9935
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9845 - dice_coef: 0.7967 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3984 - loss: 0.8334 - precision: 0.9848 - sensitivity: 0.9845 - specificity: 0.9949
# Epoch 19: val_loss did not improve from 0.93861
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9846 - dice_coef: 0.7970 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3985 - loss: 0.8329 - precision: 0.9848 - sensitivity: 0.9845 - specificity: 0.9949 - val_accuracy: 0.9808 - val_dice_coef: 0.7317 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3658 - val_loss: 0.9488 - val_precision: 0.9813 - val_sensitivity: 0.9810 - val_specificity: 0.9938
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9833 - dice_coef: 0.8042 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4021 - loss: 0.8244 - precision: 0.9836 - sensitivity: 0.9833 - specificity: 0.9945
# Epoch 20: val_loss did not improve from 0.93861
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9834 - dice_coef: 0.8045 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4022 - loss: 0.8239 - precision: 0.9836 - sensitivity: 0.9833 - specificity: 0.9945 - val_accuracy: 0.9776 - val_dice_coef: 0.7261 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3630 - val_loss: 0.9609 - val_precision: 0.9783 - val_sensitivity: 0.9780 - val_specificity: 0.9928
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9845 - dice_coef: 0.8154 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4077 - loss: 0.8055 - precision: 0.9847 - sensitivity: 0.9844 - specificity: 0.9949
# Epoch 21: val_loss improved from 0.93861 to 0.92466, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9845 - dice_coef: 0.8156 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4078 - loss: 0.8051 - precision: 0.9848 - sensitivity: 0.9844 - specificity: 0.9949 - val_accuracy: 0.9792 - val_dice_coef: 0.7473 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3737 - val_loss: 0.9247 - val_precision: 0.9798 - val_sensitivity: 0.9795 - val_specificity: 0.9933
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9850 - dice_coef: 0.8189 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4094 - loss: 0.7995 - precision: 0.9852 - sensitivity: 0.9849 - specificity: 0.9951
# Epoch 22: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9850 - dice_coef: 0.8191 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4095 - loss: 0.7991 - precision: 0.9853 - sensitivity: 0.9850 - specificity: 0.9951 - val_accuracy: 0.9781 - val_dice_coef: 0.7071 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3535 - val_loss: 0.9924 - val_precision: 0.9786 - val_sensitivity: 0.9784 - val_specificity: 0.9929
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9854 - dice_coef: 0.8216 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4108 - loss: 0.7948 - precision: 0.9857 - sensitivity: 0.9854 - specificity: 0.9952
# Epoch 23: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9855 - dice_coef: 0.8217 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4109 - loss: 0.7946 - precision: 0.9857 - sensitivity: 0.9854 - specificity: 0.9952 - val_accuracy: 0.9794 - val_dice_coef: 0.7251 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3625 - val_loss: 0.9629 - val_precision: 0.9800 - val_sensitivity: 0.9798 - val_specificity: 0.9934
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9857 - dice_coef: 0.8235 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4118 - loss: 0.7899 - precision: 0.9859 - sensitivity: 0.9856 - specificity: 0.9953
# Epoch 24: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9857 - dice_coef: 0.8236 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4118 - loss: 0.7898 - precision: 0.9859 - sensitivity: 0.9856 - specificity: 0.9953 - val_accuracy: 0.9679 - val_dice_coef: 0.6854 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3427 - val_loss: 1.0273 - val_precision: 0.9680 - val_sensitivity: 0.9678 - val_specificity: 0.9893
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9850 - dice_coef: 0.8239 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4120 - loss: 0.7908 - precision: 0.9852 - sensitivity: 0.9849 - specificity: 0.9951
# Epoch 25: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9850 - dice_coef: 0.8240 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4120 - loss: 0.7906 - precision: 0.9852 - sensitivity: 0.9849 - specificity: 0.9951 - val_accuracy: 0.9766 - val_dice_coef: 0.7365 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 0.9999 - val_iou_metric: 0.3683 - val_loss: 0.9471 - val_precision: 0.9772 - val_sensitivity: 0.9769 - val_specificity: 0.9924
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.9860 - dice_coef: 0.8266 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.4133 - loss: 0.7853 - precision: 0.9862 - sensitivity: 0.9859 - specificity: 0.9954
# Epoch 26: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.9860 - dice_coef: 0.8265 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 0.9999 - iou_metric: 0.4133 - loss: 0.7855 - precision: 0.9862 - sensitivity: 0.9859 - specificity: 0.9954 - val_accuracy: 0.9809 - val_dice_coef: 0.7234 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3617 - val_loss: 0.9574 - val_precision: 0.9812 - val_sensitivity: 0.9810 - val_specificity: 0.9937
# Epoch 27/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9862 - dice_coef: 0.8361 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4180 - loss: 0.7701 - precision: 0.9864 - sensitivity: 0.9861 - specificity: 0.9955
# Epoch 27: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9862 - dice_coef: 0.8360 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4180 - loss: 0.7702 - precision: 0.9864 - sensitivity: 0.9861 - specificity: 0.9955 - val_accuracy: 0.9810 - val_dice_coef: 0.7459 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3729 - val_loss: 0.9295 - val_precision: 0.9814 - val_sensitivity: 0.9811 - val_specificity: 0.9938
# Epoch 28/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9859 - dice_coef: 0.8399 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4200 - loss: 0.7666 - precision: 0.9861 - sensitivity: 0.9858 - specificity: 0.9954
# Epoch 28: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9859 - dice_coef: 0.8398 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4199 - loss: 0.7667 - precision: 0.9861 - sensitivity: 0.9858 - specificity: 0.9954 - val_accuracy: 0.9786 - val_dice_coef: 0.7194 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3597 - val_loss: 0.9691 - val_precision: 0.9793 - val_sensitivity: 0.9789 - val_specificity: 0.9931
# Epoch 29/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9867 - dice_coef: 0.8455 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4227 - loss: 0.7568 - precision: 0.9869 - sensitivity: 0.9866 - specificity: 0.9956
# Epoch 29: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 260ms/step - accuracy: 0.9867 - dice_coef: 0.8454 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4227 - loss: 0.7570 - precision: 0.9869 - sensitivity: 0.9866 - specificity: 0.9956 - val_accuracy: 0.9763 - val_dice_coef: 0.7174 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3587 - val_loss: 0.9731 - val_precision: 0.9766 - val_sensitivity: 0.9763 - val_specificity: 0.9922
# Epoch 30/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9863 - dice_coef: 0.8416 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4208 - loss: 0.7624 - precision: 0.9865 - sensitivity: 0.9863 - specificity: 0.9955
# Epoch 30: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9863 - dice_coef: 0.8416 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4208 - loss: 0.7626 - precision: 0.9866 - sensitivity: 0.9863 - specificity: 0.9955 - val_accuracy: 0.9796 - val_dice_coef: 0.6837 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3418 - val_loss: 1.0232 - val_precision: 0.9799 - val_sensitivity: 0.9798 - val_specificity: 0.9933
# Epoch 31/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9863 - dice_coef: 0.8418 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4209 - loss: 0.7623 - precision: 0.9865 - sensitivity: 0.9862 - specificity: 0.9955
# Epoch 31: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9863 - dice_coef: 0.8417 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4208 - loss: 0.7624 - precision: 0.9865 - sensitivity: 0.9863 - specificity: 0.9955 - val_accuracy: 0.9770 - val_dice_coef: 0.6176 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3088 - val_loss: 1.1457 - val_precision: 0.9772 - val_sensitivity: 0.9771 - val_specificity: 0.9924
# Epoch 32/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9874 - dice_coef: 0.8502 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4251 - loss: 0.7486 - precision: 0.9876 - sensitivity: 0.9874 - specificity: 0.9959
# Epoch 32: val_loss did not improve from 0.92466
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9874 - dice_coef: 0.8501 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4251 - loss: 0.7487 - precision: 0.9876 - sensitivity: 0.9874 - specificity: 0.9959 - val_accuracy: 0.9791 - val_dice_coef: 0.7043 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3521 - val_loss: 1.0017 - val_precision: 0.9794 - val_sensitivity: 0.9793 - val_specificity: 0.9931
# Epoch 33/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9874 - dice_coef: 0.8528 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4264 - loss: 0.7443 - precision: 0.9876 - sensitivity: 0.9874 - specificity: 0.9959
# Epoch 33: val_loss improved from 0.92466 to 0.91841, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 386ms/step - accuracy: 0.9874 - dice_coef: 0.8527 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4264 - loss: 0.7444 - precision: 0.9876 - sensitivity: 0.9874 - specificity: 0.9959 - val_accuracy: 0.9808 - val_dice_coef: 0.7534 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3767 - val_loss: 0.9184 - val_precision: 0.9814 - val_sensitivity: 0.9810 - val_specificity: 0.9938
# Epoch 34/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9871 - dice_coef: 0.8523 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4262 - loss: 0.7439 - precision: 0.9874 - sensitivity: 0.9871 - specificity: 0.9958
# Epoch 34: val_loss did not improve from 0.91841
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9872 - dice_coef: 0.8522 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4261 - loss: 0.7440 - precision: 0.9874 - sensitivity: 0.9871 - specificity: 0.9958 - val_accuracy: 0.9806 - val_dice_coef: 0.7365 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3683 - val_loss: 0.9422 - val_precision: 0.9812 - val_sensitivity: 0.9808 - val_specificity: 0.9937
# Epoch 35/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9876 - dice_coef: 0.8606 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4303 - loss: 0.7311 - precision: 0.9878 - sensitivity: 0.9875 - specificity: 0.9959
# Epoch 35: val_loss did not improve from 0.91841
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9876 - dice_coef: 0.8606 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4303 - loss: 0.7312 - precision: 0.9878 - sensitivity: 0.9875 - specificity: 0.9959 - val_accuracy: 0.9799 - val_dice_coef: 0.7090 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3545 - val_loss: 0.9781 - val_precision: 0.9800 - val_sensitivity: 0.9798 - val_specificity: 0.9933
# Epoch 36/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9885 - dice_coef: 0.8696 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4348 - loss: 0.7162 - precision: 0.9887 - sensitivity: 0.9885 - specificity: 0.9962
# Epoch 36: val_loss did not improve from 0.91841
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9885 - dice_coef: 0.8694 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4347 - loss: 0.7165 - precision: 0.9887 - sensitivity: 0.9885 - specificity: 0.9962 - val_accuracy: 0.9785 - val_dice_coef: 0.7048 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3524 - val_loss: 0.9980 - val_precision: 0.9786 - val_sensitivity: 0.9784 - val_specificity: 0.9929
# Epoch 37/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9886 - dice_coef: 0.8729 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4364 - loss: 0.7111 - precision: 0.9888 - sensitivity: 0.9886 - specificity: 0.9963
# Epoch 37: val_loss did not improve from 0.91841
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9886 - dice_coef: 0.8727 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4363 - loss: 0.7114 - precision: 0.9888 - sensitivity: 0.9886 - specificity: 0.9963 - val_accuracy: 0.9823 - val_dice_coef: 0.7546 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3773 - val_loss: 0.9189 - val_precision: 0.9827 - val_sensitivity: 0.9824 - val_specificity: 0.9942
# Epoch 38/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9889 - dice_coef: 0.8770 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4385 - loss: 0.7051 - precision: 0.9891 - sensitivity: 0.9889 - specificity: 0.9964
# Epoch 38: val_loss did not improve from 0.91841
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9889 - dice_coef: 0.8767 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4384 - loss: 0.7055 - precision: 0.9891 - sensitivity: 0.9889 - specificity: 0.9964 - val_accuracy: 0.9813 - val_dice_coef: 0.7466 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3733 - val_loss: 0.9201 - val_precision: 0.9816 - val_sensitivity: 0.9812 - val_specificity: 0.9939
# Epoch 39/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9883 - dice_coef: 0.8741 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4371 - loss: 0.7111 - precision: 0.9885 - sensitivity: 0.9883 - specificity: 0.9962
# Epoch 39: val_loss improved from 0.91841 to 0.91454, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 388ms/step - accuracy: 0.9883 - dice_coef: 0.8739 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4370 - loss: 0.7114 - precision: 0.9885 - sensitivity: 0.9883 - specificity: 0.9962 - val_accuracy: 0.9786 - val_dice_coef: 0.7538 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3769 - val_loss: 0.9145 - val_precision: 0.9791 - val_sensitivity: 0.9788 - val_specificity: 0.9931
# Epoch 40/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9878 - dice_coef: 0.8675 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4338 - loss: 0.7212 - precision: 0.9879 - sensitivity: 0.9877 - specificity: 0.9960
# Epoch 40: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9877 - dice_coef: 0.8673 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4336 - loss: 0.7216 - precision: 0.9879 - sensitivity: 0.9877 - specificity: 0.9960 - val_accuracy: 0.9789 - val_dice_coef: 0.7412 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3706 - val_loss: 0.9337 - val_precision: 0.9792 - val_sensitivity: 0.9789 - val_specificity: 0.9931
# Epoch 41/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9888 - dice_coef: 0.8691 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4346 - loss: 0.7160 - precision: 0.9890 - sensitivity: 0.9888 - specificity: 0.9963
# Epoch 41: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9888 - dice_coef: 0.8688 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4344 - loss: 0.7166 - precision: 0.9889 - sensitivity: 0.9887 - specificity: 0.9963 - val_accuracy: 0.9765 - val_dice_coef: 0.7372 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3686 - val_loss: 0.9448 - val_precision: 0.9769 - val_sensitivity: 0.9766 - val_specificity: 0.9923
# Epoch 42/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9891 - dice_coef: 0.8659 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4329 - loss: 0.7202 - precision: 0.9892 - sensitivity: 0.9890 - specificity: 0.9964
# Epoch 42: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9890 - dice_coef: 0.8656 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4328 - loss: 0.7207 - precision: 0.9892 - sensitivity: 0.9890 - specificity: 0.9964 - val_accuracy: 0.9759 - val_dice_coef: 0.7163 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3581 - val_loss: 0.9703 - val_precision: 0.9762 - val_sensitivity: 0.9756 - val_specificity: 0.9921
# Epoch 43/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9895 - dice_coef: 0.8630 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4315 - loss: 0.7239 - precision: 0.9897 - sensitivity: 0.9894 - specificity: 0.9966
# Epoch 43: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 261ms/step - accuracy: 0.9895 - dice_coef: 0.8629 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4314 - loss: 0.7242 - precision: 0.9896 - sensitivity: 0.9894 - specificity: 0.9965 - val_accuracy: 0.9769 - val_dice_coef: 0.7075 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3538 - val_loss: 0.9865 - val_precision: 0.9772 - val_sensitivity: 0.9766 - val_specificity: 0.9924
# Epoch 44/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9901 - dice_coef: 0.8633 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4316 - loss: 0.7225 - precision: 0.9903 - sensitivity: 0.9900 - specificity: 0.9968
# Epoch 44: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9901 - dice_coef: 0.8633 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4316 - loss: 0.7225 - precision: 0.9902 - sensitivity: 0.9900 - specificity: 0.9967 - val_accuracy: 0.9764 - val_dice_coef: 0.7124 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3562 - val_loss: 0.9788 - val_precision: 0.9767 - val_sensitivity: 0.9761 - val_specificity: 0.9922
# Epoch 45/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9899 - dice_coef: 0.8555 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4277 - loss: 0.7344 - precision: 0.9900 - sensitivity: 0.9898 - specificity: 0.9967
# Epoch 45: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9898 - dice_coef: 0.8555 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4278 - loss: 0.7344 - precision: 0.9900 - sensitivity: 0.9898 - specificity: 0.9967 - val_accuracy: 0.9798 - val_dice_coef: 0.7463 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3731 - val_loss: 0.9245 - val_precision: 0.9801 - val_sensitivity: 0.9798 - val_specificity: 0.9934
# Epoch 46/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9897 - dice_coef: 0.8607 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4304 - loss: 0.7272 - precision: 0.9899 - sensitivity: 0.9896 - specificity: 0.9966
# Epoch 46: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9897 - dice_coef: 0.8607 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4304 - loss: 0.7272 - precision: 0.9899 - sensitivity: 0.9896 - specificity: 0.9966 - val_accuracy: 0.9794 - val_dice_coef: 0.6994 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3497 - val_loss: 0.9961 - val_precision: 0.9795 - val_sensitivity: 0.9793 - val_specificity: 0.9932
# Epoch 47/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9896 - dice_coef: 0.8612 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4306 - loss: 0.7267 - precision: 0.9897 - sensitivity: 0.9895 - specificity: 0.9966
# Epoch 47: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9896 - dice_coef: 0.8612 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4306 - loss: 0.7266 - precision: 0.9897 - sensitivity: 0.9895 - specificity: 0.9966 - val_accuracy: 0.9798 - val_dice_coef: 0.7244 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3622 - val_loss: 0.9605 - val_precision: 0.9801 - val_sensitivity: 0.9798 - val_specificity: 0.9934
# Epoch 48/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9900 - dice_coef: 0.8623 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4311 - loss: 0.7243 - precision: 0.9901 - sensitivity: 0.9899 - specificity: 0.9967
# Epoch 48: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 261ms/step - accuracy: 0.9900 - dice_coef: 0.8623 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4312 - loss: 0.7243 - precision: 0.9901 - sensitivity: 0.9899 - specificity: 0.9967 - val_accuracy: 0.9805 - val_dice_coef: 0.7229 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3614 - val_loss: 0.9569 - val_precision: 0.9804 - val_sensitivity: 0.9801 - val_specificity: 0.9935
# Epoch 49/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9900 - dice_coef: 0.8556 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4278 - loss: 0.7345 - precision: 0.9902 - sensitivity: 0.9900 - specificity: 0.9967
# Epoch 49: val_loss did not improve from 0.91454
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 260ms/step - accuracy: 0.9900 - dice_coef: 0.8559 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4279 - loss: 0.7342 - precision: 0.9902 - sensitivity: 0.9899 - specificity: 0.9967 - val_accuracy: 0.9788 - val_dice_coef: 0.7112 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3556 - val_loss: 0.9823 - val_precision: 0.9787 - val_sensitivity: 0.9785 - val_specificity: 0.9929
# Epoch 50/100
# ...
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9911 - dice_coef: 0.9033 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4517 - loss: 0.6616 - precision: 0.9912 - sensitivity: 0.9911 - specificity: 0.9971
# Epoch 85: val_loss did not improve from 0.89656
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 260ms/step - accuracy: 0.9911 - dice_coef: 0.9032 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4516 - loss: 0.6618 - precision: 0.9912 - sensitivity: 0.9911 - specificity: 0.9971 - val_accuracy: 0.9820 - val_dice_coef: 0.7661 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3830 - val_loss: 0.9033 - val_precision: 0.9824 - val_sensitivity: 0.9822 - val_specificity: 0.9941
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9910 - dice_coef: 0.9043 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4521 - loss: 0.6600 - precision: 0.9911 - sensitivity: 0.9910 - specificity: 0.9970
# Epoch 86: val_loss did not improve from 0.89656
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9910 - dice_coef: 0.9042 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4521 - loss: 0.6602 - precision: 0.9911 - sensitivity: 0.9910 - specificity: 0.9970 - val_accuracy: 0.9812 - val_dice_coef: 0.7469 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3735 - val_loss: 0.9291 - val_precision: 0.9816 - val_sensitivity: 0.9814 - val_specificity: 0.9939
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9915 - dice_coef: 0.9071 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4536 - loss: 0.6540 - precision: 0.9916 - sensitivity: 0.9915 - specificity: 0.9972
# Epoch 87: val_loss improved from 0.89656 to 0.89211, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 385ms/step - accuracy: 0.9915 - dice_coef: 0.9069 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4535 - loss: 0.6543 - precision: 0.9916 - sensitivity: 0.9914 - specificity: 0.9972 - val_accuracy: 0.9826 - val_dice_coef: 0.7670 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3835 - val_loss: 0.8921 - val_precision: 0.9828 - val_sensitivity: 0.9827 - val_specificity: 0.9943
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9920 - dice_coef: 0.9108 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4554 - loss: 0.6481 - precision: 0.9921 - sensitivity: 0.9919 - specificity: 0.9974
# Epoch 88: val_loss improved from 0.89211 to 0.88616, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.9920 - dice_coef: 0.9106 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4553 - loss: 0.6484 - precision: 0.9921 - sensitivity: 0.9919 - specificity: 0.9974 - val_accuracy: 0.9809 - val_dice_coef: 0.7727 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3864 - val_loss: 0.8862 - val_precision: 0.9814 - val_sensitivity: 0.9812 - val_specificity: 0.9938
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9921 - dice_coef: 0.9111 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4555 - loss: 0.6470 - precision: 0.9922 - sensitivity: 0.9921 - specificity: 0.9974
# Epoch 89: val_loss improved from 0.88616 to 0.87003, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step - accuracy: 0.9921 - dice_coef: 0.9110 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4555 - loss: 0.6472 - precision: 0.9922 - sensitivity: 0.9921 - specificity: 0.9974 - val_accuracy: 0.9825 - val_dice_coef: 0.7824 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3912 - val_loss: 0.8700 - val_precision: 0.9832 - val_sensitivity: 0.9829 - val_specificity: 0.9944
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9924 - dice_coef: 0.9073 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4537 - loss: 0.6522 - precision: 0.9925 - sensitivity: 0.9924 - specificity: 0.9975
# Epoch 90: val_loss did not improve from 0.87003
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9924 - dice_coef: 0.9072 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4536 - loss: 0.6523 - precision: 0.9925 - sensitivity: 0.9924 - specificity: 0.9975 - val_accuracy: 0.9817 - val_dice_coef: 0.7443 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3721 - val_loss: 0.9227 - val_precision: 0.9818 - val_sensitivity: 0.9816 - val_specificity: 0.9939
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9928 - dice_coef: 0.9054 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4527 - loss: 0.6543 - precision: 0.9929 - sensitivity: 0.9928 - specificity: 0.9976
# Epoch 91: val_loss did not improve from 0.87003
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 261ms/step - accuracy: 0.9928 - dice_coef: 0.9054 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4527 - loss: 0.6544 - precision: 0.9929 - sensitivity: 0.9928 - specificity: 0.9976 - val_accuracy: 0.9819 - val_dice_coef: 0.7449 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3725 - val_loss: 0.9254 - val_precision: 0.9820 - val_sensitivity: 0.9818 - val_specificity: 0.9940
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9930 - dice_coef: 0.9061 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4531 - loss: 0.6533 - precision: 0.9931 - sensitivity: 0.9930 - specificity: 0.9977
# Epoch 92: val_loss did not improve from 0.87003
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9930 - dice_coef: 0.9062 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4531 - loss: 0.6533 - precision: 0.9931 - sensitivity: 0.9930 - specificity: 0.9977 - val_accuracy: 0.9840 - val_dice_coef: 0.7758 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3879 - val_loss: 0.8757 - val_precision: 0.9842 - val_sensitivity: 0.9840 - val_specificity: 0.9947
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9932 - dice_coef: 0.9081 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4540 - loss: 0.6500 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978
# Epoch 93: val_loss improved from 0.87003 to 0.86753, saving model to /kaggle/working/BestModels/ResNet50V2_ASPP__20250315_220222.keras
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 375ms/step - accuracy: 0.9932 - dice_coef: 0.9081 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4541 - loss: 0.6500 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978 - val_accuracy: 0.9836 - val_dice_coef: 0.7792 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3896 - val_loss: 0.8675 - val_precision: 0.9837 - val_sensitivity: 0.9835 - val_specificity: 0.9946
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9933 - dice_coef: 0.9080 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4540 - loss: 0.6498 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978
# Epoch 94: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9932 - dice_coef: 0.9081 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4540 - loss: 0.6497 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978 - val_accuracy: 0.9810 - val_dice_coef: 0.7576 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3788 - val_loss: 0.9083 - val_precision: 0.9813 - val_sensitivity: 0.9811 - val_specificity: 0.9938
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9932 - dice_coef: 0.9090 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4545 - loss: 0.6484 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978
# Epoch 95: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9932 - dice_coef: 0.9090 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4545 - loss: 0.6484 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978 - val_accuracy: 0.9801 - val_dice_coef: 0.7590 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3795 - val_loss: 0.9055 - val_precision: 0.9804 - val_sensitivity: 0.9802 - val_specificity: 0.9935
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9932 - dice_coef: 0.9058 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4529 - loss: 0.6532 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978
# Epoch 96: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 262ms/step - accuracy: 0.9932 - dice_coef: 0.9059 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4530 - loss: 0.6531 - precision: 0.9933 - sensitivity: 0.9932 - specificity: 0.9978 - val_accuracy: 0.9753 - val_dice_coef: 0.7448 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3724 - val_loss: 0.9295 - val_precision: 0.9751 - val_sensitivity: 0.9749 - val_specificity: 0.9917
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9931 - dice_coef: 0.9043 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4521 - loss: 0.6556 - precision: 0.9932 - sensitivity: 0.9930 - specificity: 0.9977
# Epoch 97: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9931 - dice_coef: 0.9044 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4522 - loss: 0.6555 - precision: 0.9931 - sensitivity: 0.9930 - specificity: 0.9977 - val_accuracy: 0.9683 - val_dice_coef: 0.7301 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3651 - val_loss: 0.9770 - val_precision: 0.9682 - val_sensitivity: 0.9681 - val_specificity: 0.9894
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9918 - dice_coef: 0.8942 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4471 - loss: 0.6737 - precision: 0.9919 - sensitivity: 0.9918 - specificity: 0.9973
# Epoch 98: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 261ms/step - accuracy: 0.9918 - dice_coef: 0.8944 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4472 - loss: 0.6733 - precision: 0.9919 - sensitivity: 0.9918 - specificity: 0.9973 - val_accuracy: 0.9803 - val_dice_coef: 0.7731 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3865 - val_loss: 0.8947 - val_precision: 0.9807 - val_sensitivity: 0.9806 - val_specificity: 0.9936
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9919 - dice_coef: 0.8889 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4445 - loss: 0.6815 - precision: 0.9919 - sensitivity: 0.9918 - specificity: 0.9973
# Epoch 99: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 261ms/step - accuracy: 0.9919 - dice_coef: 0.8892 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4446 - loss: 0.6811 - precision: 0.9919 - sensitivity: 0.9918 - specificity: 0.9973 - val_accuracy: 0.9813 - val_dice_coef: 0.7564 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3782 - val_loss: 0.9197 - val_precision: 0.9818 - val_sensitivity: 0.9817 - val_specificity: 0.9939
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9921 - dice_coef: 0.8913 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4457 - loss: 0.6774 - precision: 0.9922 - sensitivity: 0.9921 - specificity: 0.9974
# Epoch 100: val_loss did not improve from 0.86753
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.9921 - dice_coef: 0.8915 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.4457 - loss: 0.6772 - precision: 0.9922 - sensitivity: 0.9921 - specificity: 0.9974 - val_accuracy: 0.9824 - val_dice_coef: 0.7723 - val_dice_coef_edema: 1.0000 - val_dice_coef_enhancing: 1.0000 - val_dice_coef_necrotic: 1.0000 - val_dice_coef_no_tumour: 1.0000 - val_iou_metric: 0.3862 - val_loss: 0.8842 - val_precision: 0.9828 - val_sensitivity: 0.9826 - val_specificity: 0.9943
# CPU times: user 24min 55s, sys: 1min 54s, total: 26min 49s
# Wall time: 24min 54s

# %%
"""
This script evaluates the trained ResNet50_ASPP model on the validation data and prints the evaluation metrics in a tabulated format.
"""

res = ResNetAsppModelTrain.evaluate(data_gen=valDataGen, steps=val_steps_per_epoch)

headers = ["METRIC", "VALUE"]
data = [
    ["LOSS", res[0]],
    ["ACCURACY", res[1]],
    ["IOU_METRIC", res[2]],
    ["DICE_COEF", res[3]],
    ["PRECISION", res[4]],
    ["SENSITIVITY", res[5]],
    ["SPECIFICITY", res[6]],
    ["DICE_COEF_EDEMA", res[7]],
    ["DICE_COEF_ENHANCING", res[8]],
    ["DICE_COEF_NECROTIC", res[9]],
    ["DICE_COEF_NO_TUMOUR", res[10]],
]

print(tabulate(data, headers=headers, tablefmt="grid"))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9845 - dice_coef: 0.7729 - dice_coef_edema: 1.0000 - dice_coef_enhancing: 1.0000 - dice_coef_necrotic: 1.0000 - dice_coef_no_tumour: 1.0000 - iou_metric: 0.3865 - loss: 0.8725 - precision: 0.9847 - sensitivity: 0.9845 - specificity: 0.9949
# +---------------------+----------+
# | METRIC              |    VALUE |
# +=====================+==========+
# | LOSS                | 0.884165 |
# +---------------------+----------+
# | ACCURACY            | 0.982352 |
# +---------------------+----------+
# | IOU_METRIC          | 0.386153 |
# +---------------------+----------+
# | DICE_COEF           | 0.772307 |
# +---------------------+----------+
# | PRECISION           | 0.982787 |
# +---------------------+----------+
# | SENSITIVITY         | 0.982578 |
# +---------------------+----------+
# | SPECIFICITY         | 0.994263 |
# +---------------------+----------+
# | DICE_COEF_EDEMA     | 1        |
# +---------------------+----------+
# | DICE_COEF_ENHANCING | 1        |
# +---------------------+----------+
# | DICE_COEF_NECROTIC  | 1        |
# +---------------------+----------+
# | DICE_COEF_NO_TUMOUR | 1        |
# +---------------------+----------+

# %%
"""
This script defines a function to make predictions using the trained model and visualize the results.
It also runs a prediction on a random test image.
"""

def prediction(model, imagePath, maskPath, imageName):
    """
    Make predictions using the trained model and visualize the results.

    :param model: Trained model for prediction.
    :param imagePath: Path to the directory containing the images.
    :param maskPath: Path to the directory containing the masks.
    :param imageName: Name of the image file to be predicted.
    """
    maskName = imageName.replace('image', 'mask')
    img = np.load(os.path.join(imagePath, imageName))
    msk = np.load(os.path.join(maskPath, maskName))
    pred_image = np.expand_dims(img, axis=0)
    pred = model.model.predict(pred_image)[0]

    # pred[pred >= 0.5] = 1
    # pred[pred < 0.5] = 0

    print(f'IOU: {iou_metric(tf.convert_to_tensor(msk), tf.convert_to_tensor(pred))}')
    print(f'DICE: {dice_coef(tf.convert_to_tensor(msk), tf.convert_to_tensor(pred))}')

    print(f'DICE-TUMORE_CORE: {dice_coef_necrotic(tf.convert_to_tensor(msk), tf.convert_to_tensor(pred))}')
    print(f'DICE-EDEMA: {dice_coef(tf.convert_to_tensor(msk), tf.convert_to_tensor(pred))}')
    print(f'DICE-GD_ENHANCING: {dice_coef(tf.convert_to_tensor(msk), tf.convert_to_tensor(pred))}')

    train_type = 'Train'

    # Create a figure and a 1x3 grid of subplots
    if train_type == 'Train':
        fig, axes = plt.subplots(3, 4, figsize=(16, 12))
    else:
        fig, axes = plt.subplots(2, 4, figsize=(12, 6))

    # Display the image on each subplot
    axes[0][0].imshow(img[:, :, 2])
    axes[0][0].set_title(f"Image - {train_type} - T2")
    axes[0][0].axis('off')

    axes[0][1].imshow(img[:, :, 0])
    axes[0][1].set_title(f"Image - {train_type} - Flair")
    axes[0][1].axis('off')

    axes[0][2].imshow(img[:, :, 1])
    axes[0][2].set_title(f"Image - {train_type} - T1CE")
    axes[0][2].axis('off')

    if img.shape[2] == 4:
        axes[0][3].imshow(img[:, :, 3])
        axes[0][3].set_title(f"Image - {train_type} - T1")
        axes[0][3].axis('off')
    else:
        axes[0][3].imshow(img[:, :, :3])
        axes[0][3].set_title(f"Image - {train_type} - RGB")
        axes[0][3].axis('off')

    if train_type == 'Train':
        axes[1][0].imshow(msk[:, :, 1], cmap='gray')
        axes[1][0].set_title(f"Mask - {train_type} - Tumour Core")  # necrotic and non-enhancing tumor core (NCR/NET — label 1)
        axes[1][0].axis('off')

        axes[1][1].imshow(msk[:, :, 2], cmap='gray')
        axes[1][1].set_title(f"Mask - {train_type} - Edema")  # Peritumoral edema (ED — label 2)
        axes[1][1].axis('off')

        axes[1][2].imshow(msk[:, :, 3], cmap='gray')
        axes[1][2].set_title(f"Mask - {train_type} - GDE Tumour")  # Gadolinium-Enhancing Tumor (ET — label 4)
        axes[1][2].axis('off')

        axes[1][3].imshow(msk[:, :, 1:])
        axes[1][3].set_title(f"Mask - {train_type} - RGB")
        axes[1][3].axis('off')

        axes[2][0].imshow(pred[:, :, 1], cmap='gray')
        axes[2][0].set_title(f"Pred_Mask - {train_type} - Tumour Core")
        axes[2][0].axis('off')

        axes[2][1].imshow(pred[:, :, 2], cmap='gray')
        axes[2][1].set_title(f"Pred_Mask - {train_type} - Edema")
        axes[2][1].axis('off')

        axes[2][2].imshow(pred[:, :, 3], cmap='gray')
        axes[2][2].set_title(f"Pred_Mask - {train_type} - GDE Tumour")
        axes[2][2].axis('off')

        axes[2][3].imshow(pred[:, :, 1:])
        axes[2][3].set_title(f"Pred_Mask - {train_type} - RGB")
        axes[2][3].axis('off')

    plt.tight_layout()

testImgList = os.listdir(config['test_img_dir'])
prediction(resnet_aspp, config['test_img_dir'], config['test_mask_dir'], random.choice(testImgList))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# IOU: 0.37388384342193604
# DICE: 0.7477676868438721
# DICE-TUMORE_CORE: 0.4208301901817322
# DICE-EDEMA: 0.7477676868438721
# DICE-GD_ENHANCING: 0.7477676868438721

# %%
"""
This script defines a function to evaluate the trained model on training, validation, and test datasets.
It calculates various metrics and stores them in a list.
"""

METRICS = []

def evaluation_metrics(path, type):
    """
    Evaluate the trained model on the given dataset and calculate various metrics.

    :param path: Path to the directory containing the images.
    :param type: Type of dataset (TRAIN, VALIDATION, TEST).
    :return: List of calculated metrics.
    """
    os.listdir(path)
    imgPaths = [os.path.join(path, i) for i in os.listdir(path)]

    print(f"Predicting {type}")

    for k in tqdm(range(len(imgPaths))):
        i = imgPaths[k]
        img = np.load(i)
        msk = np.load(i.replace('image', 'mask'))
        img_exp = np.expand_dims(img, axis=0)
        pred_msk = resnet_aspp.model.predict(img_exp, verbose=0)[0]

        if type == "TRAIN":
            METRICS.append(
                (iou_metric(msk, pred_msk).numpy(), precision(msk, pred_msk).numpy(), sensitivity(msk, pred_msk).numpy(),
                 specificity(msk, pred_msk).numpy(),
                 dice_coef(msk, pred_msk).numpy(), dice_coef_necrotic(msk, pred_msk).numpy(), dice_coef_edema(msk, pred_msk).numpy(),
                 dice_coef_enhancing(msk, pred_msk).numpy(),
                 dice_coef_no_tumour(msk, pred_msk).numpy()
                 )
            )

        if type == "VALIDATION":
            METRICS.append(
                (iou_metric(msk, pred_msk).numpy(), precision(msk, pred_msk).numpy(), sensitivity(msk, pred_msk).numpy(),
                 specificity(msk, pred_msk).numpy(),
                 dice_coef(msk, pred_msk).numpy(), dice_coef_necrotic(msk, pred_msk).numpy(), dice_coef_edema(msk, pred_msk).numpy(),
                 dice_coef_enhancing(msk, pred_msk).numpy(),
                 dice_coef_no_tumour(msk, pred_msk).numpy()
                 )
            )

        if type == "TEST":
            METRICS.append(
                (iou_metric(msk, pred_msk).numpy(), precision(msk, pred_msk).numpy(), sensitivity(msk, pred_msk).numpy(),
                 specificity(msk, pred_msk).numpy(),
                 dice_coef(msk, pred_msk).numpy(), dice_coef_necrotic(msk, pred_msk).numpy(), dice_coef_edema(msk, pred_msk).numpy(),
                 dice_coef_enhancing(msk, pred_msk).numpy(),
                 dice_coef_no_tumour(msk, pred_msk).numpy()
                 )
            )

    return METRICS

# %%
"""
This script calculates and prints the mean of the evaluation metrics for the training dataset.
"""

train_metrics = evaluation_metrics(config["train_img_dir"], "TRAIN")

train_metrics_mean = np.mean(train_metrics, axis=0)
print(f"""
TRAIN METRICS MEAN
    IOU METRIC: {train_metrics_mean[0]}
    PRECISION: {train_metrics_mean[1]}
    SENSITIVITY: {train_metrics_mean[2]}
    SPECIFICITY: {train_metrics_mean[3]}
    DICE- WHOLE TUMOUR: {train_metrics_mean[4]}
    DICE- TUMOUR CORE: {train_metrics_mean[5]}
    DICE- EDEMA: {train_metrics_mean[6]}
    DICE- GD TUMOUR: {train_metrics_mean[7]}
    DICE- NO TUMOUR: {train_metrics_mean[8]}
""")
# Out:
# Predicting TRAIN
# 100%|██████████| 775/775 [01:31<00:00,  8.49it/s]
# TRAIN METRICS MEAN
#     IOU METRIC: 0.33861079812049866
#     PRECISION: 0.9920293092727661
#     SENSITIVITY: 0.9918987154960632
#     SPECIFICITY: 0.9973433017730713
#     DICE- WHOLE TUMOUR: 0.6770573258399963
#     DICE- TUMOUR CORE: 0.45637914538383484
#     DICE- EDEMA: 0.7664644718170166
#     DICE- GD TUMOUR: 0.4883933961391449
#     DICE- NO TUMOUR: 0.9969907402992249

# %%
"""
This script calculates and prints the mean of the evaluation metrics for the validation dataset.
"""

val_metrics = evaluation_metrics(config["val_img_dir"], "VALIDATION")

val_metrics_mean = np.mean(val_metrics, axis=0)
print(f"""
TRAIN METRICS MEAN
    IOU METRIC: {val_metrics_mean[0]}
    PRECISION: {val_metrics_mean[1]}
    SENSITIVITY: {val_metrics_mean[2]}
    SPECIFICITY: {val_metrics_mean[3]}
    DICE- WHOLE TUMOUR: {val_metrics_mean[4]}
    DICE- TUMOUR CORE: {val_metrics_mean[5]}
    DICE- EDEMA: {val_metrics_mean[6]}
    DICE- GD TUMOUR: {val_metrics_mean[7]}
    DICE- NO TUMOUR: {val_metrics_mean[8]}
""")
# Out:
# Predicting VALIDATION
# 100%|██████████| 166/166 [00:19<00:00,  8.52it/s]
# TRAIN METRICS MEAN
#     IOU METRIC: 0.329562783241272
#     PRECISION: 0.990364670753479
#     SENSITIVITY: 0.9902238845825195
#     SPECIFICITY: 0.9967887997627258
#     DICE- WHOLE TUMOUR: 0.6589876413345337
#     DICE- TUMOUR CORE: 0.42730939388275146
#     DICE- EDEMA: 0.7417417168617249
#     DICE- GD TUMOUR: 0.4704357087612152
#     DICE- NO TUMOUR: 0.9964614510536194

# %%
"""
This script calculates and prints the mean of the evaluation metrics for the testing dataset.
"""

test_metrics = evaluation_metrics(config["test_img_dir"], "TEST")

test_metrics_mean = np.mean(test_metrics, axis=0)
print(f"""
TEST METRICS MEAN
    IOU METRIC: {test_metrics_mean[0]}
    PRECISION: {test_metrics_mean[1]}
    SENSITIVITY: {test_metrics_mean[2]}
    SPECIFICITY: {test_metrics_mean[3]}
    DICE- WHOLE TUMOUR: {test_metrics_mean[4]}
    DICE- TUMOUR CORE: {test_metrics_mean[5]}
    DICE- EDEMA: {test_metrics_mean[6]}
    DICE- GD TUMOUR: {test_metrics_mean[7]},
    DICE- NO TUMOUR: {test_metrics_mean[8]}
""")
# Out:
# Predicting TEST
# 100%|██████████| 167/167 [00:19<00:00,  8.55it/s]
# TEST METRICS MEAN
#     IOU METRIC: 0.3236851692199707
#     PRECISION: 0.9889642000198364
#     SENSITIVITY: 0.9888178110122681
#     SPECIFICITY: 0.9963222742080688
#     DICE- WHOLE TUMOUR: 0.6472300887107849
#     DICE- TUMOUR CORE: 0.40923723578453064
#     DICE- EDEMA: 0.7200901508331299
#     DICE- GD TUMOUR: 0.46357962489128113,
#     DICE- NO TUMOUR: 0.9960106611251831

# %%
# !zip -rq logs.zip ./logs

# %%
# !zip -rq /kaggle/working/BestModels.zip /kaggle/working/BestModels
from IPython.display import FileLink
FileLink(r'BestModels.zip')
# Out:
# /kaggle/working/BestModels.zip
